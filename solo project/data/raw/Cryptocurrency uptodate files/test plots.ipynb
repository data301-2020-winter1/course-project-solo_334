# %%
import os
import numpy as np
from numpy.random import randn

import pandas as pd
from pandas import Series, DataFrame

from pandas_datareader.data import DataReader
from datetime import date # Date & time function

import matplotlib.pyplot as plt
from matplotlib import rcParams

import seaborn as sns

# Settings to for nice plots
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2
#rcParams['figure.figsize']= 20,15
sns.set_style('whitegrid')

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'tips', 'titanic']

# %%
crash_df = sns.load_dataset('car_crashes')
crash_df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %% [markdown]
# ### Distribution Plots
# Shift tab gets you arguments for the plot

# %%
sns.distplot(crash_df['not_distracted'], kde=False, bins = 25)
# Out:
# /Users/dawsoncitygeneralstore/opt/miniconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Joint Plot

# %%
sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind = 'resid') #kind :"scatter" | "kde" | "hist" | "hex" | "reg" | "resid"

# %% [markdown]
# ### KDE Plot

# %%
sns.kdeplot(crash_df['alcohol'])

# %% [markdown]
# ### Pair Plots

# %%
#sns.pairplot(crash_df)

tips_df = sns.load_dataset('tips')

sns.pairplot(tips_df, hue='sex', palette ='Blues')

# %% [markdown]
# ### Rug Plot

# %%
sns.rugplot(tips_df['tip'])

# %% [markdown]
# ### Styling

# %%
sns.set_style('ticks')

plt.figure(figsize=(8,4))

sns.set_context('paper', font_scale = 1.5)

sns.jointplot(x='speeding', y='alcohol',data=crash_df, kind='reg')

sns.despine(left=True, bottom=True)

# %% [markdown]
# ### bar plots

# %%
sns.barplot(x='sex', y='total_bill', data=tips_df, estimator=np.std)

# %% [markdown]
# ### Count Plot

# %%
#sns.countplot(x='sex', data=tips_df)

ax = sns.countplot(x="sex", data=tips_df,
                        facecolor=(0, 0, 0, 0),
                        linewidth=5,
                        edgecolor=sns.color_palette("dark", 3))

# %% [markdown]
# ### Box Plot

# %%
sns.boxplot(x='day', y='total_bill', data=tips_df, hue='sex')

plt.legend(loc=0)

# %% [markdown]
# ### Violin Plot

# %%
#sns.violinplot(x='day', y='total_bill', data=tips_df, hue='sex')
sns.violinplot(x='day', y='total_bill', data=tips_df, hue='sex', split=True)

# %% [markdown]
# ### Strip Plot

# %%
plt.figure(figsize=(8,5))

sns.stripplot(x='day', y='total_bill', data=tips_df, jitter=True, hue='sex', dodge=True)

# %% [markdown]
# ### Swam Plot

# %%
sns.violinplot(x='day', y='total_bill', data=tips_df)
#sns.swarmplot(x='day', y='total_bill', data=tips_df)
sns.swarmplot(x='day', y='total_bill', data=tips_df, color='white')

# %% [markdown]
# ### Palettes Plot

# %%
plt.figure(figsize=(8,7))

sns.set_style('dark')
sns.set_context('talk')
sns.stripplot(x='day', y='total_bill', data=tips_df, hue='sex', palette = 'magma')

#upper right:1, upper left: 2, upper left:3, upper right: 4, 
#https://matplotlib.org/3.3.1/api/_as_gen/matplotlib.pyplot.legend.html
plt.legend(loc=2)

# %% [markdown]
# ### Matrix Plot

# %% [markdown]
# ### Heatmaps Plot

# %%
plt.figure(figsize=(8,6))
sns.set_context('paper', font_scale=1.4)

crash_mx =crash_df.corr()


sns.heatmap(crash_mx, annot=True, cmap='Blues')

# %%
flights= sns.load_dataset('flights')
flights= flights.pivot_table(index='month', columns='year', values='passengers')
sns.heatmap(flights,cmap='Blues', linecolor='white', linewidth=1)

# %% [markdown]
# ### Cluster Plot

# %%
#iris= sns.load_dataset('iris')

#species =iris.pop('species')

#sns.clustermap(iris)

sns.clustermap(flights, cmap='Blues', standard_scale=1)

# %% [markdown]
# ### Pair Grid

# %%
iris = sns.load_dataset('iris')
iris_g = sns.PairGrid(iris, hue='species')
iris_g.map(plt.scatter)
#iris_g.map_diag(plt.hist)
iris_g.map_offdiag(plt.scatter)
iris_g.map_upper(plt.scatter)
iris_g.map_lower(sns.kdeplot)

# %%
iris_g = sns.PairGrid(iris, hue='species', 
                      x_vars=['sepal_length', 'sepal_width'],
                      y_vars=['petal_length', 'petal_width'])
iris_g.map(plt.scatter)
iris_g.add_legend()

# %% [markdown]
# ### Facet Plot

# %%
#tips_fg = sns.FacetGrid(tips_df, col='time', row='smoker')
#tips_fg.map(plt.hist, 'total_bill', bins =8)
#tips_fg.map(plt.scatter, 'total_bill', 'tip')

#tips_fg=sns.FacetGrid(tips_df, col='time', hue='smoker', height = 4, aspect=1.3,
#                    col_order=['Dinner', 'Lunch'], palette='Set1')
#tips_fg.map(plt.scatter, 'total_bill', 'tip')

# %% [markdown]
# ### Regression Plot

# %%
crypto_price = pd.read_csv('/Users/dawsoncitygeneralstore/school/Data 301/Solo_project_6008/solo project/data/raw/Cryptocurrency uptodate files/Top_5_Crypto_1_year.csv', 
    parse_dates=['Date'],
    index_col='Date'
    ).dropna()
crypto_price
# Out:
#                 Bitcoin    Ethereum     Tether       XRP  Chainlink
# Date
# 2020-11-15  15955.587890  447.559082  1.000647  0.269642   12.121813
# 2020-11-14  16068.138670  460.149841  1.000288  0.268342   12.576960
# 2020-11-13  16317.808590  474.626434  1.000345  0.265191   12.887979
# 2020-11-12  16276.343750  461.005280  1.000509  0.254903   12.423223
# 2020-11-11  15701.339840  462.960541  1.000985  0.256259   12.807538
# ...                  ...         ...       ...       ...         ...
# 2019-11-19   8206.145508  177.455551  1.008968  0.256500    2.756570
# 2019-11-18   8309.286133  180.559601  1.012008  0.255653    2.826610
# 2019-11-17   8577.975586  185.119232  1.008471  0.265253    2.931891
# 2019-11-16   8550.760742  183.348358  1.006746  0.263886    3.010331
# 2019-11-15   8491.992188  180.521179  1.001369  0.261654    3.035152
#
# [367 rows x 5 columns]

# %%
# Out:
#   File "<ipython-input-175-7f01381ca03d>", line 3
#     crypto_price.drop(['Open','High','Low', 'Volume','Market Cap'],axis=1).rename(columns={"Close": "Bitcoin Cash"}).sort_values("Date", ascending=False)
#     ^
# SyntaxError: invalid syntax

# %%
# visualize the stock_data
#plt.figure(figsize=(20,15))
rcParams['figure.figsize']= 20,15
crypto_price.plot(title='Top 5 Crypto Closing Prices', marker='.',linestyle='-',linewidth=3, markersize=3, subplots=True);

#plt.figure(figsize=(8,5))

#sns.stripplot(x='day', y='total_bill', data=tips_df, jitter=True, hue='sex', dodge=True)



# summarize the stock_data
crypto_price.describe()
# Out:
#            Bitcoin    Ethereum       Tether         XRP  Chainlink
# count    367.000000  367.000000  367.000000  367.000000  367.000000
# mean    9443.221348  250.918902    1.002035    0.225581    6.059756
# std     2103.547288   99.858012    0.004773    0.037452    4.266945
# min     4970.788086  110.605873    0.974248    0.139635    1.741144
# 25%     7765.231445  166.600266    1.000262    0.195508    2.685424
# 50%     9303.629883  228.194870    1.001419    0.223672    4.089671
# 75%    10682.633300  353.176605    1.003101    0.249244    9.707786
# max    16317.808590  477.051910    1.053585    0.334822   19.098751

# %%
sns.distplot(crypto_price['Bitcoin'], kde=False, bins = 25)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Bitcoin'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-71-22e6aa0bbf88> in <module>
# ...

# %%
sns.pairplot(crypto_price)

# %%
# Reading in the benchmark data

# Set the start date
start = date(2019,11,15)
end = date(2020,11,15)

# Set the series codes
series = 'SP500'
#For stocks, you'll use the S&P 500 Index

# Import the data
SP_data = DataReader(series, 'fred', start, end)


# Plot the results
SP_data.plot(title='S & P 500',marker='.',linestyle='-',linewidth=3, markersize=3)


# Show the plot
plt.show()


#show S&P 500 
SP_data.describe()
# Out:
#              SP500
# count   252.000000
# mean   3153.730437
# std     269.846321
# min    2237.400000
# 25%    3034.530000
# 50%    3222.335000
# 75%    3348.620000
# max    3585.150000
